# %% [markdown]
# # Bookworm
#
#
# ## Overview
#
# In this project, you will build a simple question-answering agent that is able to learn from any text data you provide, and answer queries posed in natural language. You will use IBM Watson's cloud-based services to process the input text data and find relevant responses.
#
# ## Learning Objectives
#
# By completing this project, you will learn how to:
#
# - Create a cloud-based NLP service instance and configure it.
# - Ingest a set of text documents using the service and analyze the results.
# - Accept questions in natural language and parse them.
# - Find relevant answers from the preprocessed text data.
#
# ## Getting Started
#
# In order to use Watson's cloud-based services, you first need to create an account on the [IBM Bluemix platform](https://console.ng.bluemix.net/).
#
# <div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/watson-logo.png" alt="IBM Watson logo" width="200" />
#     </div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/bluemix-logo.png" alt="IBM Bluemix logo" width="400" />
#     </div>
# </div>
#
# Then, for each service you want to use, you have to create an instance of that service. You can continue with the tasks below, and create a service instance when indicated.

# %% [markdown]
# ## 1. Create and configure Discovery service
#
# Create an instance of the **Discovery** service. You will use this to process a set of text documents, and _discover_ relevant facts and relationships.
#
# - Go to the [IBM Bluemix Catalog](https://console.ng.bluemix.net/catalog/?taxonomyNavigation=services&category=watson).
# - Select the service you want, **Discovery**, under the **Watson** category.
# - Enter a Service Name for that instance, e.g. **Disco1** and a Credential Name, e.g. **Disco1-Creds** (these are just for you to be able to refer to later, they do not affect the functioning of the service).
# - You should be able to see your newly-created service in your [Services Dashboard](https://console.ng.bluemix.net/dashboard/services).
# - Open the service instance, click on the **Service credentials** tab, and then **View credentials** under Actions. This is where you will find the username and password to use when connecting to the service.
#
# <img src="images/discovery-creds.png" alt="Discovery Service - Credentials tab" width="800" />
#
# Save the credentials for the discovery service in a JSON file in the current directory named `service-credentials.json` with the following format:
#
# ```json
# {
#     "discovery": {
#         "username": "<your Discovery username here>",
#         "password": "<your Discovery password here>"
#     },
#     "conversation": {
#         "username": "",
#         "password": ""
#     }
# }
#
# ```
#
# You will be filling out the Conversation service credentials later, when you create an instance for it. Note that you should keep these credentials secret. Please do not turn them in with your submission!
#
# ### Connect to the service instance
#
# Let's connect to the service instance you just created using IBM Watson's [Python SDK](https://github.com/watson-developer-cloud/python-sdk). You will first need to install the SDK:
# ```bash
# pip install watson-developer-cloud
# ```
#
# Now execute each code cell below using **`Shift+Enter`**, and complete any steps indicated by a **`TODO`** comment. For more information on the Discovery service, please read the [Documentation](https://www.ibm.com/watson/developercloud/doc/discovery/index.html) and look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python) as needed.

# %%
# Usual Python imports
import sys
import os
import glob
import json

# BeautifulSoup, for parsing HTML
from bs4 import BeautifulSoup

# Matplotlib, for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Watson Python SDK
import watson_developer_cloud

# Utility functions
import helper

# %%
# Connect to the Discovery service instance
# TODO: Ensure that your username and password from the Service Credentials tab are in service-credentials.json
# Note that these credentials are different from your IBM Bluemix login, and are specific to the service instance
discovery_creds = helper.fetch_credentials('discovery')
discovery = watson_developer_cloud.DiscoveryV1(
    version='2016-11-07',
    username=discovery_creds['username'],
    password=discovery_creds['password'])

# %%
# environments = discovery.get_environments()
# print(json.dumps(environments, indent=2))

# %% [markdown]
# ### Create an environment
#
# The Discovery service organizes everything needed for a particular application in an _environment_. Let's create one called "Bookworm" for this project.
#
# > _**Note**: It is okay to run this block multiple times - it will not create duplicate environments with the same name._

# %%
# Prepare an environment to work in
env, env_id = helper.fetch_object(
    discovery, "environment", "Bookworm",
    create=True, create_args=dict(
        description="A space to read and understand stories",  # feel free to edit
        size=0  # use 0 for free plan (see API reference for more on sizing)
    ))
print(json.dumps(env, indent=2))
# Out:
# Found environment: Bookworm (de930747-df06-4747-b019-803365511a82)
# {
#   "updated": "2017-07-12T00:11:25.822Z",
#   "name": "Bookworm",
#   "description": "A space to read and understand stories",
#   "read_only": false,
#   "status": "active",
#   "created": "2017-07-12T00:11:25.822Z",
#   "index_capacity": {
#     "memory_usage": {
#       "percent_used": 11.04,
#       "total_bytes": 1056309248,
#       "used": "111.19 MB",
#       "used_bytes": 116588408,
#       "total": "1007.38 MB"
#     },
#     "disk_usage": {
#       "percent_used": 0.0,
#       "total_bytes": 4294967296,
#       "used": "0 KB",
#       "used_bytes": 0,
#       "total": "4 GB"
#     }
#   },
#   "size": 0,
#   "environment_id": "de930747-df06-4747-b019-803365511a82"
# }

# %% [markdown]
# ### Verify configuration options
#
# A _configuration_ defines what natural language processing routines are applied to any documents that are submitted to the service. Each environment gets a default configuration when it is created.
#
# You can fetch the default configuration and view the different options using the following piece of code.

# %%
discovery.__getattribute__("create_collection")
# Out:
# <bound method DiscoveryV1.create_collection of <watson_developer_cloud.discovery_v1.DiscoveryV1 object at 0x101e1b320>>

# %%
# View default configuration
cfg_id = discovery.get_default_configuration_id(environment_id=env_id)
cfg = discovery.get_configuration(environment_id=env_id, configuration_id=cfg_id)
print(json.dumps(cfg, indent=2))
# Out:
# {
#   "updated": "2017-07-12T00:11:25.861Z",
#   "name": "Default Configuration",
#   "description": "The configuration used by default when creating a new collection without specifying a configuration_id.",
#   "normalizations": [],
#   "created": "2017-07-12T00:11:25.861Z",
#   "conversions": {
#     "word": {
#       "heading": {
#         "fonts": [
#           {
#             "italic": false,
#             "level": 1,
#             "min_size": 24,
#             "bold": false
#           },
#           {
#             "italic": false,
#             "bold": true,
#             "level": 2,
#             "min_size": 18,
#             "max_size": 23
#           },
#           {
#             "italic": false,
#             "bold": false,
#             "level": 3,
#             "min_size": 14,
#             "max_size": 17
#           },
#           {
#             "italic": false,
#             "bold": true,
#             "level": 4,
#             "min_size": 13,
#             "max_size": 13
#           }
#         ],
#         "styles": [
#           {
#             "names": [
#               "pullout heading",
#               "pulloutheading",
#               "header"
#             ],
#             "level": 1
#           },
#           {
#             "names": [
#               "subtitle"
#             ],
#             "level": 2
#           }
#         ]
#       }
#     },
#     "pdf": {
#       "heading": {
#         "fonts": [
#           {
#             "level": 1,
#             "min_size": 24,
#             "max_size": 80
#           },
#           {
#             "italic": false,
#             "bold": false,
#             "level": 2,
#             "min_size": 18,
#             "max_size": 24
#           },
#           {
#             "bold": true,
#             "level": 2,
#             "min_size": 18,
#             "max_size": 24
#           },
#           {
#             "italic": false,
#             "bold": false,
#             "level": 3,
#             "min_size": 13,
#             "max_size": 18
#           },
#           {
#             "bold": true,
#             "level": 3,
#             "min_size": 13,
#             "max_size": 18
#           },
#           {
#             "italic": false,
#             "bold": false,
#             "level": 4,
#             "min_size": 11,
#             "max_size": 13
#           }
#         ]
#       }
#     },
#     "html": {
#       "exclude_tags_completely": [
#         "script",
#         "sup"
#       ],
#       "exclude_tags_keep_content": [
#         "font",
#         "em",
#         "span"
#       ],
#       "exclude_tag_attributes": [
#         "EVENT_ACTIONS"
#       ],
#       "keep_content": {
#         "xpaths": []
#       },
#       "exclude_content": {
#         "xpaths": []
#       }
#     },
#     "json_normalizations": []
#   },
#   "configuration_id": "2ee4c482-0423-4673-99ff-1663ad0784fb",
#   "enrichments": [
#     {
#       "source_field": "text",
#       "destination_field": "enriched_text",
#       "options": {
#         "extract": "keyword, entity, doc-sentiment, taxonomy, concept, relation",
#         "sentiment": true,
#         "quotations": true
#       },
#       "enrichment": "alchemy_language"
#     }
#   ]
# }

# %% [markdown]
# There are 3 main configuration blocks that affect how input documents are processed:
#
# 1. **`conversions`**: How to convert documents in various formats (Word, PDF, HTML) and extract elements that indicate some structure (e.g. headings).
# 2. **`enrichments`**: What NLP output results are we interested in (keywords, entities, sentiment, etc.).
# 3. **`normalizations`**: Post-processing steps to be applied to the output. This can be left empty in most cases, unless you need the output to be normalized into a very specific format.
#
# _**Note**: The default configuration for an environment cannot be modified. If you need to change any of the options, you will need to create a new one, and then edit it. The easiest way to do this is using the service dashboard, which is described later._

# %% [markdown]
# ### Test your configuration
#
# It is a good idea to test your configuration on a small sample text before you apply it to a larger document collection.
#
# _**Note**: We have supplied a sample document (`data/sample.html`) containing the opening crawl text for Star Wars: Episode IV, but you are free to use a text of your choosing._
#
# **Q**: (optional) If you use your own sample text, provide a brief title and description below.
#
# **A**:

# %%
# Test configuration on some sample text
data_dir = "data"
filename = os.path.join(data_dir, "sample.html")
with open(filename, "r") as f:
    res = discovery.test_document(environment_id=env_id, configuration_id=cfg_id, fileinfo=f)
#print(json.dumps(res, indent=2))

# %% [markdown]
# ### Analyze test output
#
# The results returned by the service contain a _snapshot_ of the information extracted at each step of processing - document conversions, enrichments and normalizations. We are interested in the output of applying enrichments (`"enrichments_output"`) or after normalizing them (`"normalizations_output"`). These should be identical if no post-processing/normalizations were specified in the configuration.

# %%
# Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
print(json.dumps(output, indent=2))
# Out:
# {
#   "enriched_text": {
#     "language": "english",
#     "relations": [
#       {
#         "action": {
#           "verb": {
#             "tense": "present",
#             "text": "be"
#           },
#           "text": "is",
#           "lemmatized": "be"
#         },
#         "subject": {
#           "text": "It"
#         },
#         "object": {
#           "entities": [
#             {
#               "type": "FieldTerminology",
#               "text": "civil war"
#             }
#           ],
#           "keywords": [
#             {
#               "text": "civil war"
#             },
#             {
#               "text": "period"
#             }
#           ],
#           "text": "a period of civil war",
#           "sentiment": {
#             "mixed": false,
#             "type": "negative",
#             "score": -0.564509
#           }
#         },
#         "sentence": " It is a period of civil war."
#       },
#       {
#         "action": {
#           "verb": {
#             "tense": "past",
#             "text": "win"
#           },
#           "text": "have won",
#           "lemmatized": "have win"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spaceships"
#             },
#             {
#               "text": "hidden base"
#             }
#           ],
#           "text": "Rebel spaceships, striking from a hidden base,"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "victory"
#             }
#           ],
#           "text": "their first victory"
#         },
#         "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire."
#       },
#       {
#         "action": {
#           "verb": {
#             "tense": "past",
#             "text": "manage"
#           },
#           "text": "managed",
#           "lemmatized": "manage"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ],
#           "text": "Rebel spies"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "armored space station"
#             },
#             {
#               "text": "ultimate weapon"
#             },
#             {
#               "text": "secret plans"
#             },
#             {
#               "text": "entire planet"
#             }
#           ],
#           "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#           "sentiment": {
#             "mixed": false,
#             "type": "negative",
#             "score": -0.596586
#           }
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#       },
#       {
#         "action": {
#           "verb": {
#             "tense": "future",
#             "text": "steal"
#           },
#           "text": "managed to steal",
#           "lemmatized": "manage to steal"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ],
#           "text": "Rebel spies"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "secret plans"
#             }
#           ],
#           "text": "secret plans"
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#       },
#       {
#         "action": {
#           "verb": {
#             "tense": "future",
#             "text": "destroy"
#           },
#           "text": "to destroy",
#           "lemmatized": "to destroy"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ],
#           "text": "Rebel spies"
#         },
#         "object": {
#           "sentimentFromSubject": {
#             "mixed": false,
#             "type": "negative",
#             "score": -0.754579
#           },
#           "keywords": [
#             {
#               "text": "entire planet"
#             }
#           ],
#           "text": "an entire planet",
#           "sentiment": {
#             "mixed": false,
#             "type": "positive",
#             "score": 0.748639
#           }
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#       },
#       {
#         "action": {
#           "verb": {
#             "tense": "past",
#             "text": "Pursued"
#           },
#           "text": "Pursued",
#           "lemmatized": "Pursued"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Empire"
#             }
#           ],
#           "text": "by the Empire",
#           "sentiment": {
#             "mixed": false,
#             "type": "positive",
#             "score": 0.554106
#           }
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "Princess Leia"
#             }
#           ],
#           "text": "Princess Leia",
#           "sentiment": {
#             "mixed": false,
#             "type": "positive",
#             "score": 0.682563
#           }
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       },
#       {
#         "action": {
#           "verb": {
#             "tense": "future",
#             "text": "save"
#           },
#           "text": "can save",
#           "lemmatized": "can save"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "plans"
#             }
#           ],
#           "text": "the stolen plans",
#           "sentiment": {
#             "mixed": false,
#             "type": "negative",
#             "score": -0.44097
#           }
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "people"
#             }
#           ],
#           "text": "her people"
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       },
#       {
#         "action": {
#           "verb": {
#             "tense": "future",
#             "text": "restore"
#           },
#           "text": "restore",
#           "lemmatized": "restore"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "freedom"
#             }
#           ],
#           "text": "freedom"
#         },
#         "object": {
#           "sentimentFromSubject": {
#             "mixed": false,
#             "type": "positive",
#             "score": 0.698799
#           },
#           "keywords": [
#             {
#               "text": "galaxy"
#             }
#           ],
#           "text": "to the galaxy"
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       }
#     ],
#     "concepts": [
#       {
#         "website": "http://www.starwars.com/movies/episode-iv",
#         "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#         "relevance": 0.98887,
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#         "text": "Star Wars Episode IV: A New Hope"
#       },
#       {
#         "website": "http://www.starwars.com",
#         "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#         "relevance": 0.985705,
#         "text": "Star Wars",
#         "yago": "http://yago-knowledge.org/resource/Star_Wars"
#       },
#       {
#         "relevance": 0.90639,
#         "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#         "text": "Rebel Alliance",
#         "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#         "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#       },
#       {
#         "relevance": 0.805771,
#         "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#         "text": "Luke Skywalker",
#         "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#         "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#       },
#       {
#         "website": "http://www.starwars.com/movies/episode-v",
#         "relevance": 0.801062,
#         "freebase": "http://rdf.freebase.com/ns/m.0f3m1",
#         "text": "Star Wars Episode V: The Empire Strikes Back",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#       },
#       {
#         "relevance": 0.777337,
#         "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#         "text": "Darth Vader",
#         "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#         "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#       },
#       {
#         "website": "http://www.starwars.com/movies/episode-vi",
#         "relevance": 0.77159,
#         "freebase": "http://rdf.freebase.com/ns/m.0ddjy",
#         "text": "Star Wars Episode VI: Return of the Jedi",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#       },
#       {
#         "relevance": 0.748553,
#         "freebase": "http://rdf.freebase.com/ns/m.0jrsz",
#         "text": "Grand Moff Tarkin",
#         "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#         "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin"
#       },
#       {
#         "relevance": 0.697065,
#         "freebase": "http://rdf.freebase.com/ns/m.0fdv3",
#         "text": "Star Wars Episode III: Revenge of the Sith",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#       },
#       {
#         "relevance": 0.607163,
#         "text": "Princess Leia Organa",
#         "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa",
#         "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa"
#       },
#       {
#         "relevance": 0.59271,
#         "freebase": "http://rdf.freebase.com/ns/m.0f325",
#         "text": "Death Star",
#         "dbpedia": "http://dbpedia.org/resource/Death_Star",
#         "yago": "http://yago-knowledge.org/resource/Death_Star"
#       },
#       {
#         "relevance": 0.543114,
#         "freebase": "http://rdf.freebase.com/ns/m.0fjms",
#         "text": "Jabba the Hutt",
#         "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#         "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt"
#       },
#       {
#         "relevance": 0.523169,
#         "freebase": "http://rdf.freebase.com/ns/m.0hwyg",
#         "text": "Galactic Empire",
#         "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#         "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)"
#       },
#       {
#         "relevance": 0.519032,
#         "text": "Star Wars galaxy",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy",
#         "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy"
#       },
#       {
#         "website": "http://www.starwars.com/eu",
#         "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#         "relevance": 0.507885,
#         "text": "Star Wars Expanded Universe",
#         "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe"
#       },
#       {
#         "relevance": 0.503196,
#         "freebase": "http://rdf.freebase.com/ns/m.065lhy",
#         "text": "Alderaan",
#         "dbpedia": "http://dbpedia.org/resource/Alderaan",
#         "yago": "http://yago-knowledge.org/resource/Alderaan"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#         "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher",
#         "relevance": 0.481464,
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA",
#         "text": "Carrie Fisher",
#         "yago": "http://yago-knowledge.org/resource/Carrie_Fisher"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.045n4",
#         "dbpedia": "http://dbpedia.org/resource/Jedi",
#         "relevance": 0.474365,
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA",
#         "text": "Jedi",
#         "yago": "http://yago-knowledge.org/resource/Jedi"
#       },
#       {
#         "relevance": 0.4659,
#         "freebase": "http://rdf.freebase.com/ns/m.0199wf",
#         "text": "The Star Wars Holiday Special",
#         "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#         "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special"
#       },
#       {
#         "relevance": 0.46456,
#         "freebase": "http://rdf.freebase.com/ns/m.0ddp_",
#         "text": "Wedge Antilles",
#         "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#         "yago": "http://yago-knowledge.org/resource/Wedge_Antilles"
#       },
#       {
#         "relevance": 0.460469,
#         "text": "English-language films",
#         "dbpedia": "http://dbpedia.org/resource/English-language_films"
#       },
#       {
#         "relevance": 0.453766,
#         "freebase": "http://rdf.freebase.com/ns/m.0drf_",
#         "text": "Padm\u00e9 Amidala",
#         "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#         "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala"
#       },
#       {
#         "relevance": 0.447243,
#         "freebase": "http://rdf.freebase.com/ns/m.01qc6_",
#         "text": "Galactic Civil War",
#         "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#         "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War"
#       },
#       {
#         "relevance": 0.436864,
#         "freebase": "http://rdf.freebase.com/ns/m.0j_nw",
#         "text": "Spaceballs",
#         "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#         "yago": "http://yago-knowledge.org/resource/Spaceballs"
#       },
#       {
#         "relevance": 0.43403,
#         "freebase": "http://rdf.freebase.com/ns/m.01qc6n",
#         "text": "Clone Wars",
#         "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#         "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)"
#       },
#       {
#         "relevance": 0.432345,
#         "freebase": "http://rdf.freebase.com/ns/m.0g_sv",
#         "text": "C-3PO",
#         "dbpedia": "http://dbpedia.org/resource/C-3PO",
#         "yago": "http://yago-knowledge.org/resource/C-3PO"
#       },
#       {
#         "relevance": 0.431988,
#         "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#         "text": "Obi-Wan Kenobi",
#         "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#         "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#       },
#       {
#         "relevance": 0.430085,
#         "freebase": "http://rdf.freebase.com/ns/m.0g_rg",
#         "text": "R2-D2",
#         "dbpedia": "http://dbpedia.org/resource/R2-D2",
#         "yago": "http://yago-knowledge.org/resource/R2-D2"
#       }
#     ],
#     "docSentiment": {
#       "mixed": false,
#       "type": "negative",
#       "score": -0.575489
#     },
#     "status": "OK",
#     "entities": [
#       {
#         "count": 1,
#         "type": "FieldTerminology",
#         "relevance": 0.972336,
#         "sentiment": {
#           "mixed": false,
#           "type": "negative",
#           "score": -0.409172
#         },
#         "text": "civil war"
#       }
#     ],
#     "taxonomy": [
#       {
#         "label": "/art and entertainment/movies and tv/movies",
#         "score": 0.584247,
#         "confident": false
#       },
#       {
#         "label": "/society/unrest and war",
#         "score": 0.517031,
#         "confident": false
#       },
#       {
#         "label": "/law, govt and politics/armed forces/army",
#         "score": 0.215561,
#         "confident": false
#       }
#     ],
#     "keywords": [
#       {
#         "relevance": 0.920159,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "Opening Crawl"
#       },
#       {
#         "relevance": 0.785031,
#         "sentiment": {
#           "mixed": false,
#           "score": 0.447888,
#           "type": "positive"
#         },
#         "text": "New Hope"
#       },
#       {
#         "relevance": 0.775799,
#         "sentiment": {
#           "mixed": false,
#           "score": 0.40059,
#           "type": "positive"
#         },
#         "text": "Princess Leia races"
#       },
#       {
#         "relevance": 0.771384,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "Star Wars"
#       },
#       {
#         "relevance": 0.767527,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "evil Galactic Empire"
#       },
#       {
#         "relevance": 0.747615,
#         "sentiment": {
#           "mixed": false,
#           "score": -0.494714,
#           "type": "negative"
#         },
#         "text": "armored space station"
#       },
#       {
#         "relevance": 0.669776,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "Rebel spaceships"
#       },
#       {
#         "relevance": 0.656828,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "Rebel spies"
#       },
#       {
#         "relevance": 0.609404,
#         "sentiment": {
#           "mixed": false,
#           "score": 0.484685,
#           "type": "positive"
#         },
#         "text": "sinister agents"
#       },
#       {
#         "relevance": 0.600682,
#         "sentiment": {
#           "mixed": false,
#           "score": -0.409172,
#           "type": "negative"
#         },
#         "text": "civil war"
#       },
#       {
#         "relevance": 0.597836,
#         "sentiment": {
#           "mixed": false,
#           "score": 0.488854,
#           "type": "positive"
#         },
#         "text": "hidden base"
#       },
#       {
#         "relevance": 0.594694,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "ultimate weapon"
#       },
#       {
#         "relevance": 0.582765,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "secret plans"
#       },
#       {
#         "relevance": 0.582596,
#         "sentiment": {
#           "mixed": false,
#           "score": -0.494714,
#           "type": "negative"
#         },
#         "text": "entire planet"
#       },
#       {
#         "relevance": 0.574413,
#         "sentiment": {
#           "mixed": false,
#           "score": -0.430026,
#           "type": "negative"
#         },
#         "text": "DEATH STAR"
#       },
#       {
#         "relevance": 0.465394,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "custodian"
#       },
#       {
#         "relevance": 0.462247,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "Episode"
#       },
#       {
#         "relevance": 0.443969,
#         "sentiment": {
#           "mixed": false,
#           "score": 0.40059,
#           "type": "positive"
#         },
#         "text": "starship"
#       },
#       {
#         "relevance": 0.441799,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "victory"
#       },
#       {
#         "relevance": 0.437824,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "galaxy"
#       },
#       {
#         "relevance": 0.432092,
#         "sentiment": {
#           "mixed": false,
#           "score": -0.409172,
#           "type": "negative"
#         },
#         "text": "period"
#       },
#       {
#         "relevance": 0.429238,
#         "sentiment": {
#           "mixed": false,
#           "score": -0.37594,
#           "type": "negative"
#         },
#         "text": "battle"
#       },
#       {
#         "relevance": 0.428916,
#         "sentiment": {
#           "mixed": false,
#           "score": 0.40059,
#           "type": "positive"
#         },
#         "text": "home"
#       },
#       {
#         "relevance": 0.428498,
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         },
#         "text": "people"
#       }
#     ]
#   },
#   "metadata": {},
#   "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#   "extracted_metadata": {
#     "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#   },
#   "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
# }

# %% [markdown]
# Answer the following questions based on the output above. Note that it contains the input HTML, extracted text and metadata as well as the actual enrichment results (`"enriched_text"` block).
#
# #### Sentiment
#
# **Q**: What is the overall sentiment detected in this text? Mention the `type` (positive/negative) and `score`.<br />
# (_Hint: Look for the `"docSentiment"` key in the output._)
#
# **A**: Overall negative sentiment in the text:
# "score": -0.575489,
# "type": "negative",
# "mixed": false
#
#
# #### Concepts
#
# **Q**: List 3 concepts that have been identified with a relevance > 0.5. Note that not all concepts here may be present directly in the text, some may have been inferred by Watson.<br />
# (_Hint: Look for `"concepts"`._)
#
# **A**:
# - "Star Wars" with relevance 0.985705
# - "Rebel Alliance" with relevance 0.90639
# - "Luke Skywalker" with relevance 0.805771
#
#
# #### Relations
#
# Each relation is essentially a deeper analysis of a sentence (or part of a sentence). Here is a sample relation:
# ```json
# {
#   "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#   "subject": {
#     "text": "Rebel spies",
#     "keywords": [
#       {
#         "text": "Rebel spies"
#       }
#     ]
#   },
#   "action": {
#     "text": "managed to steal",
#     "lemmatized": "manage to steal",
#     "verb": {
#       "text": "steal",
#       "tense": "future"
#     }
#   },
#   "object": {
#     "text": "secret plans",
#     "keywords": [
#       {
#         "text": "secret plans"
#       }
#     ]
#   }
#  }
# ```
#
# In this case, Watson seems to have done a pretty good job of extracting some meaning from the sentence.
#
# **Q**: Find a relation where the extracted meaning is not as accurate, or not what you would've expected. List the `sentence`, `subject`, `action` and `object` parts as identified, and what you would've marked instead.<br />
# (_Hint: Look for `"relations"`._)
#
# **A**:
#
# Surprising extracted meaning:
#
# ```json
# "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#         "subject": {
#           "text": "Rebel spies",
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ]
#         },
#         "object": {
#           "text": "an entire planet",
#           "sentiment": {
#             "type": "positive",
#             "mixed": false,
#             "score": 0.748639
#           },
#           "sentimentFromSubject": {
#             "type": "negative",
#             "mixed": false,
#             "score": -0.754578
#           },
#           "keywords": [
#             {
#               "text": "entire planet"
#             }
#           ]
#         },
#         "action": {
#           "text": "to destroy",
#           "verb": {
#             "text": "destroy",
#             "tense": "future"
#           },
#           "lemmatized": "to destroy"
#         }
#       }
# ```
#
# What I would have expected for this part of the sentence is:
# "subject": "Rebel spies", "object":"secret plans" , "action":"managed to steal". This relationship is actually extracted by Watson.
#
#
# #### Keywords
#
# You may have noticed that Watson identifies some `"keywords"` in the relations, e.g. `"Rebel spies"` and `"secret plans"` in the Star Wars example above. The output also contains a list of all keywords at the top level, for your convenience, along with their relevance to the document and sentiment conveyed. Let's visualize these keywords as a word cloud!
#
# Note: We'll be using this handy [worldcoud library](https://github.com/amueller/word_cloud) to generate the visualization. So you will need to install it first:
# ```bash
# pip install wordcloud
# ```

# %%
# Visualize keywords by relevance as a wordcloud
from wordcloud import WordCloud

wc_data = { w["text"]: w["relevance"] for w in output["enriched_text"]["keywords"] }
wc = WordCloud(width=400, height=300, scale=2, background_color="white", colormap="Vega10")
wc.generate_from_frequencies(wc_data)  # use precomputed relevance instead of frequencies

plt.figure(figsize=(4, 3), dpi=200)
plt.imshow(wc, interpolation='bilinear')
plt.title("Cloud by word relevance")
plt.axis("off")
# Out:
# /Users/morganelustman/anaconda3/envs/aind-dl/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The Vega10 colormap was deprecated in version 2.0. Use tab10 instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# (-0.5, 799.5, 599.5, -0.5)

# %%
# Cloud by word frequency instead of relevance above

data_dir = "data"
filename = os.path.join(data_dir, "sample.html")
with open(filename, "r") as f:
    res = f.read()

wc = WordCloud(width=400, height=300, scale=2, background_color="white", colormap="Vega10")
wc.generate(res)

plt.figure(figsize=(4, 3), dpi=200)
plt.imshow(wc, interpolation='bilinear')
plt.title("Cloud by word frequency")
plt.axis("off")
# Out:
# /Users/morganelustman/anaconda3/envs/aind-dl/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The Vega10 colormap was deprecated in version 2.0. Use tab10 instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# Feel free to play with this visualization and improve it. What about using a different metric instead of relevance, e.g. direct word frequencies that the wordcloud library computes by default?
#
# #### Other results
#
# Watson's output also includes processed results from other enrichments that were applied to the text, including entities and taxonomy (what topic or category does this text relate to).
#
# ```json
# "taxonomy": [
#   {
#     "label": "/art and entertainment/movies and tv/movies",
#     "score": 0.584247,
#     "confident": false
#   },
#   {
#     "label": "/society/unrest and war",
#     "score": 0.517031,
#     "confident": false
#   },
#   {
#     "confident": false,
#     "label": "/law, govt and politics/armed forces/army",
#     "score": 0.215561
#   }
# ],
# ```
#
# Get a good sense of all the different pieces of information available in the results. Start thinking about which ones will be useful for looking up answers to questions, and how you might use them.

# %% [markdown]
# ## 2. Ingest documents
#
# ### Create a collection
#
# A _collection_ is used to organize documents of the same kind. For instance, you may want to create a collection of book reviews, or a collection of Wikipedia articles, but it may not make much sense to mix the two groups. This allows Watson to make meaningful inferences over the set of documents, find commonalities and identify important concepts.
#
# Let's create one called "Story Chunks".

# %%
#  Prepare a collection of documents to use
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id,
    create=True, create_args=dict(
        environment_id=env_id, configuration_id=cfg_id,
        description="Stories and plots split up into chunks suitable for answering"
    ))
print(json.dumps(col, indent=2))

# fix discovery.py in ./anaconda3/envs/aind-dl/lib/python3.5/site-packages/watson_developer_cloud/discovery_v1.py
# Out:
# Created collection: Story Chunks (f40778f8-d19f-4322-b7c1-74ad267d36ce)
# {
#   "updated": "2017-07-12T00:19:22.927Z",
#   "name": "Story Chunks",
#   "description": "Stories and plots split up into chunks suitable for answering",
#   "status": "active",
#   "collection_id": "f40778f8-d19f-4322-b7c1-74ad267d36ce",
#   "created": "2017-07-12T00:19:22.927Z",
#   "language": "en",
#   "configuration_id": "2ee4c482-0423-4673-99ff-1663ad0784fb"
# }

# %% [markdown]
# Once you have created a collection, you should be able to view it using the Discovery Service tool. To open, go to the **Manage** tab for your service instance, and click the **Launch tool** button.
#
# <img src="images/discovery-manage.png" alt="Discovery service - Manage tab" width="800" />

# %% [markdown]
# Here you should see the "Story Chunks" collection you just created.
#
# <img src="images/discovery-tooling.png" alt="Discovery service - Tool showing collections" width="800" />
#
# You can open the collection to view more details about it. If you need to modify configuration options, click the **Switch** link and create a new configuration (the default one cannot be changed).

# %% [markdown]
# ### Add documents
#
# Okay, now that we have everything set up, let's add a set of "documents" we want Watson to look up answers from, using the Python SDK. Note that Watson treats each "document" as a unit of text that is returned as the result of a query. But we want to retrieve a paragraph of text for each question. So, let's split each file up into individual paragraphs. We will use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library for this purpose.
#
# _**Note**: You could also add and manage documents in the collection using the Discovery tool, but you would have to split paragraphs up into separate files._
#
# _**Note**: We have provided a set of files (`data/Star-Wars/*.html`) with summary plots for Star Wars movies, but you are free to use a collection of your choice. Open one of the files in a text editor to see how the paragraphs are delimited using `<p>...</p>` tags - this is how the code block below split paragraphs into separate "documents"._

# %%
# Add documents to collection
doc_ids = []  # to store the generated id for each document added
for filename in glob.glob(os.path.join(data_dir, "Star-Wars", "*.html")):
    print("Adding file:", filename)
    with open(filename, "r") as f:
        # Split each individual <p> into its own "document"
        doc = f.read()
        soup = BeautifulSoup(doc, 'html.parser')
        for i, p in enumerate(soup.find_all('p')):
            doc_info = discovery.add_document(environment_id=env_id, collection_id=col_id,
                file_data=json.dumps({"text": p.get_text(strip=True)}),
                mime_type="application/json",
                metadata={"title": soup.title.get_text(strip=True)})
            doc_ids.append(doc_info["document_id"])
print("Total", len(doc_ids), "documents added.")
# Out:
# Adding file: data/Star-Wars/Episode-I_The-Phantom-Menace.html
# Adding file: data/Star-Wars/Episode-II_Attack-of-the-Clones.html
# Adding file: data/Star-Wars/Episode-III_Revenge-of-the-Sith.html
# Adding file: data/Star-Wars/Episode-IV_A-New-Hope.html
# Adding file: data/Star-Wars/Episode-V_The-Empire-Strikes-Back.html
# Adding file: data/Star-Wars/Episode-VI_Return-of-the-Jedi.html
# Adding file: data/Star-Wars/Episode-VII_The-Force-Awakens.html
# Adding file: data/Star-Wars/Rogue-One.html
# Total 42 documents added.

# %% [markdown]
# If you look at the collection details, you may notice that the `"document_counts"` field now shows some documents as `available` or `processing`. Once processing is complete, you should see all the documents under the `available` count.

# %%
# View collection details to verify all documents have been processed
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id)
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (f40778f8-d19f-4322-b7c1-74ad267d36ce)
# {
#   "updated": "2017-07-12T00:19:22.927Z",
#   "training_status": {
#     "total_examples": 0,
#     "available": false,
#     "minimum_examples_added": false,
#     "minimum_queries_added": false,
#     "data_updated": "",
#     "sufficient_label_diversity": false,
#     "processing": false,
#     "notices": 0,
#     "successfully_trained": ""
#   },
#   "language": "en",
#   "description": "Stories and plots split up into chunks suitable for answering",
#   "document_counts": {
#     "failed": 0,
#     "processing": 0,
#     "available": 42
#   },
#   "status": "active",
#   "collection_id": "f40778f8-d19f-4322-b7c1-74ad267d36ce",
#   "created": "2017-07-12T00:19:22.927Z",
#   "name": "Story Chunks",
#   "configuration_id": "2ee4c482-0423-4673-99ff-1663ad0784fb"
# }

# %% [markdown]
# So, what did the Discovery service learn? If you list the fields extracted from the set of documents in the collection as part of the enrichment process, you'll see familiar fields like `concepts`, `entities` and `keywords` that were returned in the test analysis.

# %%
# List all fields extracted
discovery.list_collection_fields(environment_id=env_id, collection_id=col_id)
# Out:
# {'fields': [{'field': 'f40778f8-d19f-4322-b7c1-74ad267d36ce.mappings.document._all.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text', 'type': 'nested'},
#   {'field': 'extracted_metadata', 'type': 'nested'},
#   {'field': 'metadata', 'type': 'nested'},
#   {'field': 'text', 'type': 'string'},
#   {'field': 'text.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.concepts', 'type': 'nested'},
#   {'field': 'enriched_text.properties.docSentiment', 'type': 'nested'},
#   {'field': 'enriched_text.properties.entities', 'type': 'nested'},
#   {'field': 'enriched_text.properties.keywords', 'type': 'nested'},
#   {'field': 'enriched_text.properties.language', 'type': 'string'},
#   {'field': 'enriched_text.properties.language.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.relations', 'type': 'nested'},
#   {'field': 'enriched_text.properties.status', 'type': 'string'},
#   {'field': 'enriched_text.properties.status.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.taxonomy', 'type': 'nested'},
#   {'field': 'extracted_metadata.properties.file_type', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.file_type.analyzer',
#    'type': 'english'},
#   {'field': 'extracted_metadata.properties.filename', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.filename.analyzer',
#    'type': 'english'},
#   {'field': 'extracted_metadata.properties.sha1', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.sha1.analyzer', 'type': 'english'},
#   {'field': 'metadata.properties.title', 'type': 'string'},
#   {'field': 'metadata.properties.title.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.ciaFactbook',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.ciaFactbook.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.geo',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.geo.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.musicBrainz',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.musicBrainz.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.opencyc',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.opencyc.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.concepts.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.website',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.website.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.docSentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.docSentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.docSentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.docSentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.count',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.keywords.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.sentence',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.sentence.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.taxonomy.properties.confident',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.taxonomy.properties.label',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.taxonomy.properties.label.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.taxonomy.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.lemmatized',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.lemmatized.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.tense',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.tense.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.score',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.score.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'}]}

# %% [markdown]
# ### Test query
#
# Let's perform a simple query to see if the service can fetch the proper document for us:
# > _Look for all paragraphs that have a relation (sentence) with "Jar Jar" as the subject, and return the title and text._

# %%
# A simple query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.relations.action.verb.text:\"infiltrates\"",
        "return": "metadata.title,text"
    })
print(json.dumps(results, indent=2))
# Out:
# {
#   "matching_results": 3,
#   "results": [
#     {
#       "metadata": {
#         "title": "Star Wars: Episode III - Revenge of the Sith"
#       },
#       "id": "962e2693-8ebf-417d-8df0-48b656f2971d",
#       "score": 2.2868607,
#       "text": "Three years after the the start of the Clone Wars between the Galactic Republic and the Confederacy of Independent Systems, war has gripped the galaxy. During a space battle over the planet Coruscant, Jedi Knights Obi-Wan Kenobi and Anakin Skywalker lead a mission to rescue the kidnapped Supreme Chancellor Palpatine from Separatist commander General Grievous. After infiltrating Grievous's flagship, the Jedi battle Count Dooku. Anakin subdues Dooku, and on Palpatine's urging, executes him. Grievous flees the battle-torn cruiser, which the Jedi crash-land on Coruscant. There, Anakin reunites with his wife, Padm\u00e9 Amidala, who reveals she is pregnant. While initially excited, Anakin begins to have prophetic visions of Padm\u00e9 dying in childbirth, and his worry steadily grows."
#     },
#     {
#       "metadata": {
#         "title": "Star Wars: Episode VII - The Force Awakens"
#       },
#       "id": "2fd09449-edea-42f9-8598-3390dfa4245d",
#       "score": 1.8294885,
#       "text": "At the Resistance base on D'Qar, BB-8 finds R2-D2, who has been inactive since Luke's disappearance. As Starkiller Base prepares to fire on D'Qar, the Resistance devises a plan to destroy the superweapon by attacking a critical facility. Leia urges Han to return their son alive. Using the Falcon, Han, Chewbacca, and Finn infiltrate the facility, find Rey, and plant explosives. Han confronts Ren, calling him by his birth name, Ben, and implores him to abandon the dark side. Ren refuses and kills Han, enraging Chewbacca, who fires and hits Ren. He sets off the explosives, allowing the Resistance to attack and destroy Starkiller Base."
#     },
#     {
#       "metadata": {
#         "title": "Star Wars: Episode VI - Return of the Jedi"
#       },
#       "id": "e1eb4628-aa5a-4f0c-bb89-f54d0f1ee572",
#       "score": 1.3721163,
#       "text": "Luke Skywalker initiates a plan to rescue Han Solo from the crime lord Jabba the Hutt with the help of Princess Leia, Lando Calrissian, Chewbacca, C-3PO, and R2-D2. Leia infiltrates Jabba's palace on Tatooine disguised as a bounty hunter with Chewbacca as her prisoner. Lando is already there disguised as a guard. Leia releases Han from his carbonite prison, but she is captured and enslaved. Luke arrives soon afterward but after a tense standoff, he is captured. After Luke survives his battle with Jabba's Rancor, Jabba sentences him and Han to death by feeding them to the Sarlacc. Luke frees himself and battles Jabba's guards. During the chaos, Boba Fett, who has remained at Jabba's palace since delivering Han, attempts to attack Luke, but Han inadvertently knocks him into the Sarlacc pit. Meanwhile, Leia strangles Jabba to death, and Luke destroys Jabba's sail barge as the group escapes. While the others rendezvous with the Rebel Alliance, Luke returns to Dagobah where he finds that Yoda is dying. Before he dies, Yoda confirms that Darth Vader, once known as Anakin Skywalker, is Luke's father, and there is \"another Skywalker\". The spirit of Obi-Wan Kenobi confirms that this other Skywalker is Luke's twin sister, Leia. Obi-Wan tells Luke that he must fight Vader again to defeat the Empire."
#     }
#   ]
# }

# %% [markdown]
# Change the above query and see what results you get! Try to find one that returns relevant results, and keep that (along with the output) for review.
#
# > See [Query building reference](https://www.ibm.com/watson/developercloud/doc/discovery/query-reference.html) for descriptions of all possible parameters, operators and aggregations. You can also choose to build the query using the web interface (click the "Story Chunks" collection to query it), and then reproduce the query here.
#
# Then answer the questions below:
#
# **Q**: What query did you try? Express it in plain words below.
#
# **A**: Get all the results with the verb "inflitrate" as the action.
#
#
# **Q**: What answer did you get back from Watson? You only need to mention the relevant snippet of text fro mthe paragraph(s) returned.
#
# **A**: 3 results: "After infiltrating Grievous's flagship", "Han, Chewbacca, and Finn infiltrate the facility", "Leia infiltrates Jabba's palace"

# %% [markdown]
# ## 3. Parse natural language questions
#
# In order to understand questions posed in natural language, we'll use another Watson service called [Conversation](https://www.ibm.com/watson/developercloud/doc/conversation/index.html). It can be used to design conversational agents or _chatbots_ that exhibit complex behavior, but for the purpose of this project, we'll only use it to parse certain kinds of queries.
#
# ### Create a Conversation service instance
#
# Just like you did for the Discovery service, create an instance of the Conversation service. Then launch the associated tool from the service dashboard.
#
# <img src="images/conversation-tooling.png" alt="Conversation service - Tool homepage" width="800" />
#
# A _workspace_ allows you to keep all the items you need for a particular application in one place, just like an _environment_ in case of the Discovery service. Create one called "Bookworm" with a suitable description, such as "I know a lot of stories. Ask me a question!"
#
# <img src="images/conversation-workspace.png" alt="Conversation service - Blank workspace" width="800" />
#
# This should open up a blank workspace, where you can add intents, define the entities you want the agent to idenitfy and structure the overall dialog.
#
# ### Add intents
#
# An _intent_ is the goal or purpose of a user's input. Create a set of intents (at least 3) that capture the different kinds of questions that you want the system to answer, e.g. _who_, _what_ and _where_. Along with each intent, add a list of user examples or _utterances_ that map to that intent.
#
# For instance, you could enter the following examples for the _where_ intent:
#
# - Where is the Jedi temple located?
# - Where was Luke born?
#
# The Conversation service recommends at least 5 examples for each intent so that Watson learns how to recognize it. These don't have to be very precise, but more examples the better.
#
# <img src="images/conversation-intents.png" alt="Conversation service - Intents listed" width="800" />
#
# Feel free to create your own intents, based on the kinds of questions you want the system to answer, e.g. "How many ...", "What are the most common ..." etc. Each intent will need to be mapped to an appropriate query.
#
# > See [**Defining intents**](https://www.ibm.com/watson/developercloud/doc/conversation/intents.html) for a helpful video and further instructions.
#
# **Q**: What intents did you add to the Conversation service instance?
#
# **A**:How Many? Where? Who?
#
#
#
# **Q**: Pick one of these intents, and list at least 5 examples for the intent that you entered.
#
# **A**:
# Who kills Jango Fett?
# Who is Luke's father?
# Who is the leader of the Galactic Republic?
# Who is Supreme Chancellor Valorum's apprentice?
# Who does Anakin marry?
# Who are Anakin and Padmé witnesses?
#
#
# ### Add entities
#
# Once you have your intents set, let's tell the service what entities we want it to identify. One way to do this is using the tool interface, and entering them one-by-one.
#
# > Go to [**Defining entities**](https://www.ibm.com/watson/developercloud/doc/conversation/entities.html) to see how that is done.
#
# But that can be tedious! So let's refer back to the entities that the Discovery service identified, and load them in programmatically.
#
# As before, let's connect to the Conversation service first. Remember to enter your service credentials below.

# %%
# Connect to the Conversation service instance
# TODO: Enter your username and password from the Service Credentials tab in service-credentials.json
conversation_creds = helper.fetch_credentials('conversation')
conversation = watson_developer_cloud.ConversationV1(
    version='2017-02-03',
    username=conversation_creds['username'],
    password=conversation_creds['password'])

# %% [markdown]
# Fetch the workspace you just created called "Bookworm".

# %%
wrk, wrk_id = helper.fetch_object(conversation, "workspace", "Bookworm")
print(json.dumps(wrk, indent=2))
# Out:
# Found workspace: Bookworm (e7d921d7-8106-4e0b-97c8-aed82b2b3036)
# {
#   "updated": "2017-07-12T00:41:27.662Z",
#   "metadata": null,
#   "name": "Bookworm",
#   "description": "I know a lot of stories. Ask me a question!",
#   "workspace_id": "e7d921d7-8106-4e0b-97c8-aed82b2b3036",
#   "status": "Available",
#   "created": "2017-06-21T02:25:46.940Z",
#   "language": "en"
# }

# %% [markdown]
# Collect all the entities from the Discovery service collection.

# %%
# Get all the entities from the collection and group them by type
response = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "return": "enriched_text.entities.type,enriched_text.entities.text"
    })

# Group individual entities by type ("Person", "Location", etc.)
entities_by_type = {}
for document in response["results"]:
    for entity in document["enriched_text"]["entities"]:
        if entity["type"] not in entities_by_type:
            entities_by_type[entity["type"]] = set()
        entities_by_type[entity["type"]].add(entity["text"])

# Ignore case to avoid duplicates
for entity_type in entities_by_type:
    entities_by_type[entity_type] = {
        e.lower(): e for e in entities_by_type[entity_type]
    }.values()

# Restructure for loading into Conversation workspace
entities_grouped = [{
    "entity": entity_type,
    "values": [{"value": entity} for entity in entities]}
        for entity_type, entities in entities_by_type.items()]
entities_grouped
# Out:
# [{'entity': 'JobTitle',
#   'values': [{'value': 'chancellor'},
#    {'value': 'engineer'},
#    {'value': 'officer'}]},
#  {'entity': 'City',
#   'values': [{'value': 'Padmé'},
#    {'value': 'Podrace'},
#    {'value': 'Theed'},
#    {'value': 'Alderaan'},
#    {'value': 'Mustafar'},
#    {'value': 'Gungans'},
#    {'value': 'Tusken'},
#    {'value': 'Geonosis'},
#    {'value': 'Valorum'},
#    {'value': 'Gungan'}]},
#  {'entity': 'Person',
#   'values': [{'value': 'Han'},
#    {'value': 'Zam Wesell'},
#    {'value': 'Senator Padmé Amidala'},
#    {'value': 'Amidala'},
#    {'value': 'Gunray'},
#    {'value': 'Vader'},
#    {'value': 'Anakin'},
#    {'value': 'Cliegg Lars'},
#    {'value': 'Palpatine'},
#    {'value': 'Queen Amidala'},
#    {'value': 'Jango Fett'},
#    {'value': 'Chancellor Valorum'},
#    {'value': 'Supreme Chancellor Palpatine'},
#    {'value': 'Padmé'},
#    {'value': 'Luke Skywalker'},
#    {'value': 'Obi-Wan Kenobi'},
#    {'value': 'Darth Sidious'},
#    {'value': 'Senator Palpatine'},
#    {'value': 'Watto'},
#    {'value': 'Luke'},
#    {'value': 'Geonosis'},
#    {'value': 'Boss Nass'},
#    {'value': 'Anakin Skywalker'},
#    {'value': 'Obi-Wan'},
#    {'value': 'Leia'},
#    {'value': 'Shmi'},
#    {'value': 'Count Dooku'},
#    {'value': 'Boba'},
#    {'value': 'Beru Lars'},
#    {'value': 'Qui-Gon'},
#    {'value': 'Mace Windu'},
#    {'value': 'Darth Maul'},
#    {'value': 'Viceroy Nute Gunray'}]},
#  {'entity': 'Facility', 'values': [{'value': 'Grand Moff Tarkin'}]},
#  {'entity': 'Company',
#   'values': [{'value': 'Jawa traders'},
#    {'value': 'Mos Espa'},
#    {'value': 'Federation Viceroy Nute Gunray'},
#    {'value': 'Falcon'}]},
#  {'entity': 'FieldTerminology', 'values': [{'value': 'the queen'}]},
#  {'entity': 'Quantity',
#   'values': [{'value': 'one'},
#    {'value': 'Ten years'},
#    {'value': 'nine-year'}]},
#  {'entity': 'Organization',
#   'values': [{'value': 'Federation'},
#    {'value': 'Jedi Council'},
#    {'value': 'Tusken Raiders'},
#    {'value': 'Force'},
#    {'value': 'Galactic Senate'},
#    {'value': 'droid army'},
#    {'value': 'Galactic Republic'},
#    {'value': 'Trade Federation'}]},
#  {'entity': 'Country', 'values': [{'value': 'Naboo'}]}]

# %% [markdown]
# Update the workspace with these entities and verify that have been added correctly.

# %%
# Add these grouped entities to the Conversation workspace
conversation.update_workspace(workspace_id=wrk_id, entities=entities_grouped)

workspace_details = conversation.get_workspace(workspace_id=wrk_id, export=True)
print(json.dumps(workspace_details["entities"], indent=2))
# Out:
# [
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "FieldTerminology",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "the queen",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "civil war",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   },
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "City",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "Gungans",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Geonosis",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Coruscant",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Podrace",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Alderaan",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Mustafar",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Valorum",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Theed",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Kashyyyk",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Tusken",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Padm\u00e9",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   },
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "Country",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "Naboo",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   },
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "JobTitle",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "representative",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Chancellor",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "engineer",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   },
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "Quantity",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "Three years",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "nine-year",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "one",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Ten years",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   },
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "Person",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "Anakin",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Owen",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Mace Windu",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Qui-Gon",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Gunray",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Vader",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Viceroy Nute Gunray",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Obi-Wan Kenobi",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Princess Leia",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Geonosis",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Organa",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Anakin Skywalker",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Polis Massa",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Supreme Chancellor Palpatine",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Cliegg Lars",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Obi-Wan",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Boba",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Senator Padm\u00e9 Amidala",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Queen Amidala",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Palpatine",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Beru Lars",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Luke",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Amidala",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Zam Wesell",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Watto",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Jango Fett",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Padm\u00e9",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Darth Sidious",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Count Dooku",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Darth Maul",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Chancellor Valorum",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Leia",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Darth Vader",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Mustafar",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Senator Palpatine",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Yoda",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Shmi",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   },
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "Facility",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "Jedi Temple",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Galactic Empire",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   },
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "Organization",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "Rebel Alliance",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Galactic Senate",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "droid army",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Trade Federation",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Force",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Tusken Raiders",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Jedi Council",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       },
#       {
#         "value": "Senate",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   },
#   {
#     "updated": "2017-06-21T02:47:30.204Z",
#     "entity": "Company",
#     "source": null,
#     "created": "2017-06-21T02:47:30.204Z",
#     "values": [
#       {
#         "value": "Mos Espa",
#         "synonyms": [],
#         "created": "2017-06-21T02:47:30.204Z",
#         "metadata": null,
#         "updated": "2017-06-21T02:47:30.204Z"
#       }
#     ],
#     "type": null,
#     "open_list": null,
#     "description": null
#   }
# ]

# %% [markdown]
# _**Note**: Ensure that at least 3 entity types, with at least 1 example entity each have been added._
#
# Here is what the list of entities should look like through the Conversation tool.
#
# <img src="images/conversation-entities.png" alt="Conversation service - Entities listed" width="800" />
#
# **Q**: Name 3 entity types that were added, with at least 1 example entity each (e.g. entity type: _City_, example: _Los Angeles_).
#
# **A**:
# - entity type: Job Title, example: representative, chancellor, engineer
# - entity type: Quantity, example: three years, nine-year, Ten years
# - entity type: Facility, example: Jedi Temple, Galactic Empire

# %% [markdown]
# ### Design dialog flow
#
# As a final step in creating the Conversation interface, let's design a typical dialog with a user. The most intuitive way to do this is to use the Dialog tab in the tool. Here, you can add _nodes_ that capture different stages in the dialog flow, and connect them in a meaningful way.
#
# Go ahead and add at least 3 dialog nodes. Specify the triggers in terms of the intents and entities that you'd like to match, and an optional intermediate response like "Let me find that out for you." The actual response will be fetched by querying the Discovery service.
#
# Here is what the dialog nodes should look like.
#
# <img src="images/conversation-dialog_nodes.png" alt="Conversation service - Dialog nodes" width="640" />
#
# **Q**: Specify 3 dialog nodes you added, along with the trigger (intent and/or entities) for each.
#
# **A**: Person (#who), Location (#where), Count (#howmany)

# %% [markdown]
# ### Test dialog
#
# Let's run through a test dialog to demonstrate how the system transitions to one of the nodes you defined above.

# %%
# Testing the dialog flow

# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "Who is Luke's father?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "entities": [
#     {
#       "location": [
#         7,
#         11
#       ],
#       "confidence": 1,
#       "entity": "Person",
#       "value": "Luke"
#     }
#   ],
#   "output": {
#     "nodes_visited": [
#       "Person"
#     ],
#     "text": [
#       "Let me find that person for you"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "09640e8b-8779-4f68-941f-b79b9a9a09fc",
#     "system": {
#       "_node_output_map": {
#         "Person": [
#           0
#         ]
#       },
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_request_counter": 1,
#       "dialog_turn_counter": 1,
#       "branch_exited_reason": "completed",
#       "branch_exited": true
#     }
#   },
#   "input": {
#     "context": {
#       "conversation_id": "039c0da1-3c8d-4feb-94ba-f30650979f24",
#       "system": {
#         "_node_output_map": {
#           "Anything else": [
#             0
#           ]
#         },
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ],
#         "dialog_request_counter": 1,
#         "dialog_turn_counter": 1,
#         "branch_exited_reason": "completed",
#         "branch_exited": true
#       }
#     },
#     "text": "Who is Luke's father?"
#   },
#   "intents": [
#     {
#       "intent": "who",
#       "confidence": 1
#     }
#   ]
# }

# %% [markdown]
# ## 4. Query document collection to fetch answers
#
# The Discovery service includes a simple mechanism to make queries against your enriched collection of documents. But you have a lot of control over what fields are searched, how results are aggregated and values are returned.
#
# ### Process sample question
#
# Choose a sample nautal language question to ask, and run it through the Conversation service, just like you did above when testing dialog flow.

# %%
# TODO: Run a sample question through Conversation service
# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "Who is Luke's sister?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "entities": [
#     {
#       "location": [
#         7,
#         11
#       ],
#       "confidence": 1,
#       "entity": "Person",
#       "value": "Luke"
#     }
#   ],
#   "output": {
#     "nodes_visited": [
#       "Person"
#     ],
#     "text": [
#       "Let me find that person for you"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "c3e81593-72fc-451d-89b9-d6e1b96e652d",
#     "system": {
#       "_node_output_map": {
#         "Person": [
#           0
#         ]
#       },
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_request_counter": 1,
#       "dialog_turn_counter": 1,
#       "branch_exited_reason": "completed",
#       "branch_exited": true
#     }
#   },
#   "input": {
#     "context": {
#       "conversation_id": "ed785df4-455d-4f44-87e0-eeaa3c8f4091",
#       "system": {
#         "_node_output_map": {
#           "Anything else": [
#             0
#           ]
#         },
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ],
#         "dialog_request_counter": 1,
#         "dialog_turn_counter": 1,
#         "branch_exited_reason": "completed",
#         "branch_exited": true
#       }
#     },
#     "text": "Who is Luke's sister?"
#   },
#   "intents": [
#     {
#       "intent": "who",
#       "confidence": 0.9190130233764648
#     }
#   ]
# }

# %% [markdown]
# Now extract the intent and entities identified in the question, and optionally what dialog node was triggered (in case you need it later to customize your response). Some sample code is provided below, but you may need to modify it.

# %%
# TODO: Identify the intent(s) the user expressed (typically a single one)
query_intents = [intent["intent"] for intent in results["intents"]]
print("Intent(s):", query_intents)

# TODO: Extract the entities found in the question text
query_entities = [entity["value"] for entity in results["entities"]]
print("Entities:", query_entities)

# TODO: (optional) Find out what dialog node was triggered
nodes_visited = results["output"]["nodes_visited"]
print("nodes_visited:", nodes_visited)
# Out:
# Intent(s): ['who']
# Entities: ['Luke']
# nodes_visited: ['Person']

# %% [markdown]
# ### Query the collection
#
# Design a query based on the information extracted above, and run it against the document collection. The sample query provided below simple looks for all the entities in the raw `text` field. Modify it to suit your needs.
#
# Take a look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python#query-collection) to learn more about the query options available, and for more guidance see this [documentation page](https://www.ibm.com/watson/developercloud/doc/discovery/using.html).
#
# _**Note**: You may want to design different queries based on the intent / dialog node that was triggered._

# %%
# TODO: Query the Discovery service based on the intent and entities
question= "Who is Luke's sister?"
query_results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "natural_language_query": question,
        "return": "enriched_text.relations"
#         "query": "text:{}".format(",".join("\"{}\"".format(e) for e in query_entities)),
#         "return": "text"
    })
print(json.dumps(query_results, indent=2))
# Out:
# {
#   "matching_results": 38,
#   "results": [
#     {
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "initiate"
#               },
#               "lemmatized": "initiate",
#               "text": "initiates"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Anakin Skywalker"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke Skywalker"
#                 }
#               ],
#               "text": "Luke Skywalker"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Princess Leia"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Lando Calrissian"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "crime lord Jabba"
#                 },
#                 {
#                   "text": "Lando Calrissian"
#                 },
#                 {
#                   "text": "Princess Leia"
#                 },
#                 {
#                   "text": "Han Solo"
#                 }
#               ],
#               "text": "a plan to rescue Han Solo from the crime lord Jabba the Hutt with the help of Princess Leia, Lando Calrissian, Chewbacca, C-3PO, and R2-D2"
#             },
#             "sentence": "Luke Skywalker initiates a plan to rescue Han Solo from the crime lord Jabba the Hutt with the help of Princess Leia, Lando Calrissian, Chewbacca, C-3PO, and R2-D2."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "rescue"
#               },
#               "lemmatized": "to rescue",
#               "text": "to rescue"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "crime"
#                 }
#               ],
#               "text": "from the crime"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.731939,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Han Solo"
#                 }
#               ],
#               "text": "Han Solo"
#             },
#             "sentence": "Luke Skywalker initiates a plan to rescue Han Solo from the crime lord Jabba the Hutt with the help of Princess Leia, Lando Calrissian, Chewbacca, C-3PO, and R2-D2."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "infiltrate"
#               },
#               "lemmatized": "infiltrate",
#               "text": "infiltrates"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Princess Leia"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Leia"
#                 }
#               ],
#               "text": "Leia"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Jabba"
#                 },
#                 {
#                   "text": "Tatooine"
#                 },
#                 {
#                   "text": "palace"
#                 }
#               ],
#               "text": "Jabba's palace on Tatooine"
#             },
#             "sentence": " Leia infiltrates Jabba's palace on Tatooine disguised as a bounty hunter with Chewbacca as her prisoner."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "past",
#                 "text": "disguise"
#               },
#               "lemmatized": "disguise",
#               "text": "disguised"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Tatooine"
#                 }
#               ],
#               "text": "Tatooine"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.545709,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "bounty hunter"
#                 },
#                 {
#                   "text": "Chewbacca"
#                 },
#                 {
#                   "text": "prisoner"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.583012,
#                 "type": "positive"
#               },
#               "text": "as a bounty hunter with Chewbacca as her prisoner"
#             },
#             "sentence": " Leia infiltrates Jabba's palace on Tatooine disguised as a bounty hunter with Chewbacca as her prisoner."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be",
#               "text": "is"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Lando Calrissian"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Lando"
#                 }
#               ],
#               "text": "Lando"
#             },
#             "sentence": " Lando is already there disguised as a guard."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "arrive"
#               },
#               "lemmatized": "arrive",
#               "text": "arrives"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "sentence": " Luke arrives soon afterward but after a tense standoff, he is captured."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "past",
#                 "text": "capture"
#               },
#               "lemmatized": "be capture",
#               "text": "is captured"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "text": "he"
#             },
#             "sentence": " Luke arrives soon afterward but after a tense standoff, he is captured."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "survive"
#               },
#               "lemmatized": "survive",
#               "text": "survives"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "battle"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.475193,
#                 "type": "negative"
#               },
#               "text": "his battle"
#             },
#             "sentence": " After Luke survives his battle with Jabba's Rancor, Jabba sentences him and Han to death by feeding them to the Sarlacc."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "sentence"
#               },
#               "lemmatized": "sentence",
#               "text": "sentences"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Jabba"
#                 }
#               ],
#               "text": "Jabba"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.428959,
#                 "type": "negative"
#               },
#               "text": "him"
#             },
#             "sentence": " After Luke survives his battle with Jabba's Rancor, Jabba sentences him and Han to death by feeding them to the Sarlacc."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "feed"
#               },
#               "lemmatized": "feed",
#               "text": "feeding"
#             },
#             "subject": {
#               "text": "them"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "City",
#                   "text": "Sarlacc"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.56893,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Sarlacc"
#                 }
#               ],
#               "text": "to the Sarlacc"
#             },
#             "sentence": " After Luke survives his battle with Jabba's Rancor, Jabba sentences him and Han to death by feeding them to the Sarlacc."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "free"
#               },
#               "lemmatized": "free",
#               "text": "frees"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "battles"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.412411,
#                 "type": "negative"
#               },
#               "text": "himself and battles"
#             },
#             "sentence": " Luke frees himself and battles Jabba's guards."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "battle"
#               },
#               "lemmatized": "battle",
#               "text": "battles"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.36792,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "Jabba"
#                 },
#                 {
#                   "text": "guards"
#                 }
#               ],
#               "text": "Jabba's guards"
#             },
#             "sentence": " Luke frees himself and battles Jabba's guards."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "deliver"
#               },
#               "lemmatized": "deliver",
#               "text": "delivering"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Boba Fett"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Boba Fett"
#                 }
#               ],
#               "text": "Boba Fett,"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.657136,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han"
#             },
#             "sentence": " During the chaos, Boba Fett, who has remained at Jabba's palace since delivering Han, attempts to attack Luke, but Han inadvertently knocks him into the Sarlacc pit."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "attempt"
#               },
#               "lemmatized": "attempt",
#               "text": "attempts"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Boba Fett"
#                 },
#                 {
#                   "type": "Facility",
#                   "text": "Jabba's palace"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Boba Fett"
#                 },
#                 {
#                   "text": "Jabba"
#                 },
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.401149,
#                 "type": "negative"
#               },
#               "text": "Boba Fett, who has remained at Jabba's palace since delivering Han,"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.476587,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.583758,
#                 "type": "negative"
#               },
#               "text": "to attack Luke"
#             },
#             "sentence": " During the chaos, Boba Fett, who has remained at Jabba's palace since delivering Han, attempts to attack Luke, but Han inadvertently knocks him into the Sarlacc pit."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "attack"
#               },
#               "lemmatized": "attempt to attack",
#               "text": "attempts to attack"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Boba Fett"
#                 },
#                 {
#                   "type": "Facility",
#                   "text": "Jabba's palace"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Boba Fett"
#                 },
#                 {
#                   "text": "Jabba"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.336602,
#                 "type": "negative"
#               },
#               "text": "Boba Fett, who has remained at Jabba"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.587815,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "sentence": " During the chaos, Boba Fett, who has remained at Jabba's palace since delivering Han, attempts to attack Luke, but Han inadvertently knocks him into the Sarlacc pit."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "knock"
#               },
#               "lemmatized": "knock",
#               "text": "knocks"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.700287,
#                 "type": "negative"
#               },
#               "text": "him"
#             },
#             "sentence": " During the chaos, Boba Fett, who has remained at Jabba's palace since delivering Han, attempts to attack Luke, but Han inadvertently knocks him into the Sarlacc pit."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "strangle"
#               },
#               "lemmatized": "strangle",
#               "text": "strangles"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Princess Leia"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Leia"
#                 }
#               ],
#               "text": "Leia"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.551268,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "Jabba"
#                 },
#                 {
#                   "text": "death"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.537095,
#                 "type": "negative"
#               },
#               "text": "Jabba to death"
#             },
#             "sentence": " Meanwhile, Leia strangles Jabba to death, and Luke destroys Jabba's sail barge as the group escapes."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "destroy"
#               },
#               "lemmatized": "destroy",
#               "text": "destroys"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.658224,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "sail barge"
#                 },
#                 {
#                   "text": "Jabba"
#                 }
#               ],
#               "text": "Jabba's sail barge"
#             },
#             "sentence": " Meanwhile, Leia strangles Jabba to death, and Luke destroys Jabba's sail barge as the group escapes."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "return"
#               },
#               "lemmatized": "return",
#               "text": "returns"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "sentence": " While the others rendezvous with the Rebel Alliance, Luke returns to Dagobah where he finds that Yoda is dying."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "find"
#               },
#               "lemmatized": "find",
#               "text": "finds"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "text": "he"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.687519,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Yoda"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.749554,
#                 "type": "negative"
#               },
#               "text": "that Yoda is dying"
#             },
#             "sentence": " While the others rendezvous with the Rebel Alliance, Luke returns to Dagobah where he finds that Yoda is dying."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "confirm"
#               },
#               "lemmatized": "confirm",
#               "text": "confirms"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Yoda"
#                 }
#               ],
#               "text": "Yoda"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Darth Vader"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Anakin Skywalker"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Darth Vader"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.671681,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Anakin Skywalker"
#                 },
#                 {
#                   "text": "Darth Vader"
#                 },
#                 {
#                   "text": "Luke"
#                 },
#                 {
#                   "text": "father"
#                 }
#               ],
#               "text": "that Darth Vader, once known as Anakin Skywalker, is Luke's father, and there is \"another Skywalker\""
#             },
#             "sentence": " Before he dies, Yoda confirms that Darth Vader, once known as Anakin Skywalker, is Luke's father, and there is \"another Skywalker\"."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "past",
#                 "text": "know"
#               },
#               "lemmatized": "once know",
#               "text": "once known"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Darth Vader"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Darth Vader"
#                 }
#               ],
#               "text": "Darth Vader"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Anakin Skywalker"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Anakin Skywalker"
#                 }
#               ],
#               "text": "as Anakin Skywalker"
#             },
#             "sentence": " Before he dies, Yoda confirms that Darth Vader, once known as Anakin Skywalker, is Luke's father, and there is \"another Skywalker\"."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be",
#               "text": "is"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Darth Vader"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Darth Vader"
#                 }
#               ],
#               "text": "Darth Vader"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Skywalker"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.517372,
#                 "type": "negative"
#               },
#               "text": "another Skywalker\""
#             },
#             "sentence": " Before he dies, Yoda confirms that Darth Vader, once known as Anakin Skywalker, is Luke's father, and there is \"another Skywalker\"."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "confirm"
#               },
#               "lemmatized": "confirm",
#               "text": "confirms"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Obi-Wan Kenobi"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Obi-Wan Kenobi"
#                 },
#                 {
#                   "text": "spirit"
#                 }
#               ],
#               "text": "The spirit of Obi-Wan Kenobi"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Princess Leia"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.671681,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "twin sister"
#                 },
#                 {
#                   "text": "Leia"
#                 },
#                 {
#                   "text": "Skywalker"
#                 },
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.394898,
#                 "type": "negative"
#               },
#               "text": "that this other Skywalker is Luke's twin sister, Leia"
#             },
#             "sentence": " The spirit of Obi-Wan Kenobi confirms that this other Skywalker is Luke's twin sister, Leia."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "fight"
#               },
#               "lemmatized": "must fight",
#               "text": "must fight"
#             },
#             "subject": {
#               "text": "he"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Darth Vader"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.560671,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "text": "Vader"
#             },
#             "sentence": " Obi-Wan tells Luke that he must fight Vader again to defeat the Empire."
#           }
#         ]
#       },
#       "id": "e1eb4628-aa5a-4f0c-bb89-f54d0f1ee572",
#       "score": 1.1878976
#     },
#     {
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "take"
#               },
#               "lemmatized": "take",
#               "text": "takes"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Vader"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "text": "Vader"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "sentence": "Vader takes Luke to the Death Star to meet the Emperor, intent on turning him to the dark side."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "meet"
#               },
#               "lemmatized": "to meet",
#               "text": "to meet"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Emperor"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.57805,
#                 "type": "negative"
#               },
#               "text": "the Emperor"
#             },
#             "sentence": "Vader takes Luke to the Death Star to meet the Emperor, intent on turning him to the dark side."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "turn"
#               },
#               "lemmatized": "turn",
#               "text": "turning"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Vader"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "text": "Vader"
#             },
#             "object": {
#               "text": "him"
#             },
#             "sentence": "Vader takes Luke to the Death Star to meet the Emperor, intent on turning him to the dark side."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "reveal"
#               },
#               "lemmatized": "reveal",
#               "text": "reveals"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Emperor"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.57805,
#                 "type": "negative"
#               },
#               "text": "The Emperor"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.592674,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Rebel fleet"
#                 },
#                 {
#                   "text": "Death Star"
#                 },
#                 {
#                   "text": "trap"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.387054,
#                 "type": "negative"
#               },
#               "text": "that the Death Star is actually fully operational and the Rebel fleet will fall into a trap"
#             },
#             "sentence": " The Emperor reveals that the Death Star is actually fully operational and the Rebel fleet will fall into a trap."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be",
#               "text": "is"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "strike team"
#                 },
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han's strike team"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Imperial forces"
#                 }
#               ],
#               "text": "captured by Imperial forces"
#             },
#             "sentence": " On Endor, Han's strike team is captured by Imperial forces, but a surprise counterattack by the Ewoks allows the Rebels to battle the Imperials."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "past",
#                 "text": "capture"
#               },
#               "lemmatized": "be capture",
#               "text": "is captured"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Imperial forces"
#                 }
#               ],
#               "text": "by Imperial forces"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.759791,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "strike team"
#                 },
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han's strike team"
#             },
#             "sentence": " On Endor, Han's strike team is captured by Imperial forces, but a surprise counterattack by the Ewoks allows the Rebels to battle the Imperials."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "allow"
#               },
#               "lemmatized": "allow",
#               "text": "allows"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "surprise counterattack"
#                 },
#                 {
#                   "text": "Ewoks"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.520271,
#                 "type": "negative"
#               },
#               "text": "a surprise counterattack by the Ewoks"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Organization",
#                   "disambiguated": {
#                     "name": "Rebel Alliance",
#                     "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#                     "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#                     "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#                   },
#                   "text": "Rebels"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Rebels"
#                 }
#               ],
#               "text": "the Rebels"
#             },
#             "sentence": " On Endor, Han's strike team is captured by Imperial forces, but a surprise counterattack by the Ewoks allows the Rebels to battle the Imperials."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "battle"
#               },
#               "lemmatized": "to battle",
#               "text": "to battle"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Organization",
#                   "disambiguated": {
#                     "name": "Rebel Alliance",
#                     "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#                     "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#                     "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#                   },
#                   "text": "Rebels"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Rebels"
#                 }
#               ],
#               "text": "the Rebels"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.690922,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "Imperials"
#                 }
#               ],
#               "text": "the Imperials"
#             },
#             "sentence": " On Endor, Han's strike team is captured by Imperial forces, but a surprise counterattack by the Ewoks allows the Rebels to battle the Imperials."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "pilot"
#               },
#               "lemmatized": "pilot",
#               "text": "piloting"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Lando"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Lando"
#                 }
#               ],
#               "text": "Lando"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.493148,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Millennium Falcon"
#                 }
#               ],
#               "text": "the Millennium Falcon"
#             },
#             "sentence": " Meanwhile, Lando, piloting the Millennium Falcon, leads the Rebel fleet to the Death Star, only to find that the station's shield is still active and the Imperial fleet is waiting for them."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "lead"
#               },
#               "lemmatized": "lead",
#               "text": "leads"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Lando"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Millennium Falcon"
#                 },
#                 {
#                   "text": "Lando"
#                 }
#               ],
#               "text": "Lando, piloting the Millennium Falcon,"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Rebel fleet"
#                 }
#               ],
#               "text": "the Rebel fleet"
#             },
#             "sentence": " Meanwhile, Lando, piloting the Millennium Falcon, leads the Rebel fleet to the Death Star, only to find that the station's shield is still active and the Imperial fleet is waiting for them."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be",
#               "text": "is"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "station"
#                 }
#               ],
#               "text": "the station's shield"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Imperial fleet"
#                 }
#               ],
#               "text": "still active and the Imperial fleet"
#             },
#             "sentence": " Meanwhile, Lando, piloting the Millennium Falcon, leads the Rebel fleet to the Death Star, only to find that the station's shield is still active and the Imperial fleet is waiting for them."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be",
#               "text": "is"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Imperial fleet"
#                 },
#                 {
#                   "text": "shield"
#                 },
#                 {
#                   "text": "station"
#                 }
#               ],
#               "text": "the station's shield is still active and the Imperial fleet"
#             },
#             "object": {
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.480743,
#                 "type": "positive"
#               },
#               "text": "waiting for them"
#             },
#             "sentence": " Meanwhile, Lando, piloting the Millennium Falcon, leads the Rebel fleet to the Death Star, only to find that the station's shield is still active and the Imperial fleet is waiting for them."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "wait"
#               },
#               "lemmatized": "be wait",
#               "text": "is waiting"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Imperial fleet"
#                 }
#               ],
#               "text": "the Imperial fleet"
#             },
#             "object": {
#               "text": "for them"
#             },
#             "sentence": " Meanwhile, Lando, piloting the Millennium Falcon, leads the Rebel fleet to the Death Star, only to find that the station's shield is still active and the Imperial fleet is waiting for them."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "tempt"
#               },
#               "lemmatized": "tempt",
#               "text": "tempts"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Emperor"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.57805,
#                 "type": "negative"
#               },
#               "text": "The Emperor"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "sentence": " The Emperor tempts Luke to give in to his anger and join the dark side of the Force, and Luke engages Vader in a lightsaber duel."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "give"
#               },
#               "lemmatized": "to give",
#               "text": "to give"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Emperor"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.57805,
#                 "type": "negative"
#               },
#               "text": "The Emperor"
#             },
#             "sentence": " The Emperor tempts Luke to give in to his anger and join the dark side of the Force, and Luke engages Vader in a lightsaber duel."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "engage"
#               },
#               "lemmatized": "engage",
#               "text": "engages"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Vader"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.553642,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "text": "Vader"
#             },
#             "sentence": " The Emperor tempts Luke to give in to his anger and join the dark side of the Force, and Luke engages Vader in a lightsaber duel."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "have"
#               },
#               "lemmatized": "have",
#               "text": "has"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Luke"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
# ...
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "devise"
#               },
#               "lemmatized": "devise",
#               "text": "devises"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Resistance"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.554628,
#                 "type": "positive"
#               },
#               "text": "the Resistance"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.676416,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "critical facility"
#                 },
#                 {
#                   "text": "plan"
#                 },
#                 {
#                   "text": "superweapon"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.764306,
#                 "type": "negative"
#               },
#               "text": "a plan to destroy the superweapon by attacking a critical facility"
#             },
#             "sentence": " As Starkiller Base prepares to fire on D'Qar, the Resistance devises a plan to destroy the superweapon by attacking a critical facility."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "attack"
#               },
#               "lemmatized": "attack",
#               "text": "attacking"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Company",
#                   "text": "Starkiller Base"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Starkiller Base"
#                 }
#               ],
#               "text": "Starkiller Base"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.780535,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "critical facility"
#                 }
#               ],
#               "text": "a critical facility"
#             },
#             "sentence": " As Starkiller Base prepares to fire on D'Qar, the Resistance devises a plan to destroy the superweapon by attacking a critical facility."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "urge"
#               },
#               "lemmatized": "urge",
#               "text": "urges"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Leia"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Leia"
#                 }
#               ],
#               "text": "Leia"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.440223,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han"
#             },
#             "sentence": " Leia urges Han to return their son alive."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "return"
#               },
#               "lemmatized": "to return",
#               "text": "to return"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "son"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.568628,
#                 "type": "positive"
#               },
#               "text": "their son alive"
#             },
#             "sentence": " Leia urges Han to return their son alive."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "infiltrate"
#               },
#               "lemmatized": "infiltrate",
#               "text": "infiltrate"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Finn"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Chewbacca"
#                 },
#                 {
#                   "text": "Han"
#                 },
#                 {
#                   "text": "Finn"
#                 },
#                 {
#                   "text": "Falcon"
#                 }
#               ],
#               "text": "the Falcon, Han, Chewbacca, and Finn"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "facility"
#                 }
#               ],
#               "text": "the facility"
#             },
#             "sentence": " Using the Falcon, Han, Chewbacca, and Finn infiltrate the facility, find Rey, and plant explosives."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "find"
#               },
#               "lemmatized": "find",
#               "text": "find"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Finn"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Chewbacca"
#                 },
#                 {
#                   "text": "Han"
#                 },
#                 {
#                   "text": "Finn"
#                 },
#                 {
#                   "text": "Falcon"
#                 }
#               ],
#               "text": "the Falcon, Han, Chewbacca, and Finn infiltrate the facility,"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Rey"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "plant explosives"
#                 },
#                 {
#                   "text": "Rey"
#                 }
#               ],
#               "text": "Rey, and plant explosives"
#             },
#             "sentence": " Using the Falcon, Han, Chewbacca, and Finn infiltrate the facility, find Rey, and plant explosives."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "confront"
#               },
#               "lemmatized": "confront",
#               "text": "confronts"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Ren"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.55052,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "Ren"
#                 }
#               ],
#               "text": "Ren"
#             },
#             "sentence": " Han confronts Ren, calling him by his birth name, Ben, and implores him to abandon the dark side."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "call"
#               },
#               "lemmatized": "call",
#               "text": "calling"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Ren"
#                 }
#               ],
#               "text": "him"
#             },
#             "sentence": " Han confronts Ren, calling him by his birth name, Ben, and implores him to abandon the dark side."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "implore"
#               },
#               "lemmatized": "implore",
#               "text": "implores"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Ben"
#                 }
#               ],
#               "text": "him"
#             },
#             "sentence": " Han confronts Ren, calling him by his birth name, Ben, and implores him to abandon the dark side."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "abandon"
#               },
#               "lemmatized": "to abandon",
#               "text": "to abandon"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Ben"
#                 }
#               ],
#               "text": "him"
#             },
#             "object": {
#               "text": "the dark side"
#             },
#             "sentence": " Han confronts Ren, calling him by his birth name, Ben, and implores him to abandon the dark side."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "kill"
#               },
#               "lemmatized": "kill",
#               "text": "kills"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Ren"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Ren"
#                 }
#               ],
#               "text": "Ren"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Han"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.294241,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "Chewbacca"
#                 },
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "text": "Han, enraging Chewbacca, who fires and hits"
#             },
#             "sentence": " Ren refuses and kills Han, enraging Chewbacca, who fires and hits Ren."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "set"
#               },
#               "lemmatized": "set",
#               "text": "sets"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Ren"
#                 }
#               ],
#               "text": "He"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.684041,
#                 "type": "positive"
#               },
#               "keywords": [
#                 {
#                   "text": "explosives"
#                 }
#               ],
#               "text": "the explosives"
#             },
#             "sentence": " He sets off the explosives, allowing the Resistance to attack and destroy Starkiller Base."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "present",
#                 "text": "allow"
#               },
#               "lemmatized": "allow",
#               "text": "allowing"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Ren"
#                 }
#               ],
#               "text": "He"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "GeographicFeature",
#                   "text": "Starkiller Base"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Starkiller Base"
#                 },
#                 {
#                   "text": "Resistance"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.589776,
#                 "type": "negative"
#               },
#               "text": "the Resistance to attack and destroy Starkiller Base"
#             },
#             "sentence": " He sets off the explosives, allowing the Resistance to attack and destroy Starkiller Base."
#           },
#           {
#             "action": {
#               "verb": {
#                 "tense": "future",
#                 "text": "attack"
#               },
#               "lemmatized": "to attack",
#               "text": "to attack"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Resistance"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.554628,
#                 "type": "positive"
#               },
#               "text": "the Resistance"
#             },
#             "object": {
#               "entities": [
#                 {
#                   "type": "GeographicFeature",
#                   "text": "Starkiller Base"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.583758,
#                 "type": "negative"
#               },
#               "keywords": [
#                 {
#                   "text": "Starkiller Base"
#                 }
#               ],
#               "text": "Starkiller Base"
#             },
#             "sentence": " He sets off the explosives, allowing the Resistance to attack and destroy Starkiller Base."
#           }
#         ]
#       },
#       "id": "2fd09449-edea-42f9-8598-3390dfa4245d",
#       "score": 0.3651998
#     }
#   ]
# }

# %% [markdown]
# ### Process returned results
#
# If you properly structure the query, Watson is able to do a pretty good job of finding the relevant information. But the result returned is a JSON object. Now your task is to convert that result into an appropriate response that best addresses the original natural language question that was asked.
#
# E.g. if the question was "Who saved Han Solo from Jabba the Hutt?" the answer should ideally just be "The Rebels" and not the entire paragraph describing Han Solo's rescue. But that can be a backup response if you cannot be more specific.
#
# _**Note**: You may have to go back to the previous step and modify the query, especially what you want the Discovery service to return, and this may depend on the intent / dialog node triggered. E.g. study the different parts of a "relation" structure to see how you might construct queries to match them._

# %%
# TODO: Process returned results and compose an appropriate response

# Question: Who is Luke's sister?

kwd = 'sister'
obj = 'Luke'

relations = [relation for results in query_results['results'] 
 for relation in results['enriched_text']['relations'] 
 if 'object' in relation
 if 'keywords' in relation['object']
 for kwds in relation['object']['keywords']
 if kwd in kwds['text']
 
 if 'subject' in relation
 if 'entities' in relation['subject']
 for ents in relation['subject']['entities']
 if obj in ents['text']
 
if 'entities' in relation['object']
]

if relations is None:
    print("Could not find the answer")
else:
    print("Answer:", relations[0]["object"]["entities"][0]["text"])
# Out:
# Answer: Leia

# %% [markdown]
# ## 5. Reflections
#
# **Q**: Now that you have gone through this exercise of designing a system that uses two IBM Watson services, what did you learn? What were some of the strengths and weaknesses of this approach?
#
# **A**: I learnt how to use 2 IBM Watson services: "Discovery" to process a set of text documents, and discover relevant facts and relationships and "Conversation" to recognize the questions asked.
# I think that the "Discovery" service is very useful, especially getting some information such as the sentiment, and being able to identify the key concepts, as well as the structure of the sentences. Sometimes, the parsing of the sentence is inaccurate but overall it's quite good. The "Conversation", however, relies on a lot of manual work, hard-coding some types of questions and answers etc. Hopefully, this service will improve a lot in the future, and naturally recognize the types of questions using deep-learning.
#
#
# ## (Optional) Extensions
#
# We have provided a set of sample data files containing Star Wars plot summaries. But as mentioned before, you are free to use your own dataset. In fact, a larger dataset maybe more suitable for use with IBM Watson's NLP services. If you used your own dataset, answer the following questions.
#
# **Q**: What dataset did you use, and in what ways is it different from the sample files provided?
#
# **A**:
#
#
# **Q**: Either include your dataset in the .zip file or repository you submit, or provide clear instructions on how to obtain the dataset, so that your reviewer can run your notebook or inspect the data to verify your results.
#
# **A**:
#
#
# _You can also design a web-based application that utilizes these services and deploy that on Bluemix! If you do, please share with your instructors and peers._
